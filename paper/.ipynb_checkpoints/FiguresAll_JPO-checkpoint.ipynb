# %% [markdown]
# ## All the figures for the paper
# **05 March 2024 by MiniUFO**
#
# ---
# [TOC]
#
# ---
# ### 1. Introduction
# Following [Beron-Vera and LaCasce](https://journals.ametsoc.org/view/journals/phoc/46/7/jpo-d-15-0127.1.xml), relative dispersion analysis will be performed using GLAD drifter dataset.  Also, the newly proposed [Cumulative Inverse Separation Time (CIST)](https://www.cambridge.org/core/journals/journal-of-fluid-mechanics/article/abs/relative-dispersion-with-finite-inertial-ranges/A4810AD4971C9C9FC920CE4BDAF8AE95) diagnostic will be calculated to infer the turbulent regime of the real ocean.  This notebooks contains all the figures used in the JPO paper.
#
# ---
#
# ### 2. Plot the results
# #### 2.1 Load the results

# %%
import xarray as xr
import numpy as np
import sys
sys.path.append('../')
from xdispersion import RelativeDispersion
import warnings
warnings.filterwarnings("ignore")
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

rd = RelativeDispersion(xpos='longitude', uvel='ve', time='time', Rearth=6371.2,
                        ypos='latitude' , vvel='vn', coord='latlon')

binmethod = 'cist'
alpha = 1.2

r0_gla = 0.13
groupG = f'{r0_gla}'
dataset = 'GLAD'
dsGRo = xr.open_dataset(f'../data/RDstat_{dataset}_{binmethod}bin_{alpha}_o{groupG}.nc')
dsGRc = xr.open_dataset(f'../data/RDstat_GLAD_10d_{binmethod}bin_{alpha}_oandc_minfst0.13.nc')

dsGRAl = xr.open_dataset(f'../data/RDstat_{dataset}_{binmethod}bin_{alpha}_FSLE.nc')

r0_las = 0.2
groupL = f'{r0_las}'
dataset = 'LASER'
dsLRo  = xr.open_dataset(f'../data/RDstat_{dataset}rft_10d_{binmethod}bin_{alpha}_o{groupL}.nc')
dsLRc  = xr.open_dataset(f'../data/RDstat_LASERrft_10d_{binmethod}bin_{alpha}_oandc_minfst0.2.nc')
dsLRAl = xr.open_dataset(f'../data/RDstat_{dataset}rft_10d_{binmethod}bin_{alpha}_FSLE.nc')

rG_o = np.sqrt(dsGRo.r2)
rG_c = np.sqrt(dsGRc.r2)
rL_o = np.sqrt(dsLRo.r2)
rL_c = np.sqrt(dsLRc.r2)

tbins = rd.separation_bins(0.01, 100, alpha, method=binmethod, thre=30, incre=4)
sbins = rd.separation_bins(0.1, 800, alpha, method=binmethod)

# %% [markdown]
# #### 2.4 Plot results

# %%
# velocity correlation
import proplot as pplt
from xdispersion import panel

v1 = {'var':dsGRo.nums, 'r':rG_o, 'method':'plot', 'label':'GLAD original', 's':9, 'color':'r'}
v2 = {'var':dsGRc.nums, 'r':rG_c, 'method':'plot', 'label':'GLAD chance'  , 's':8, 'color':'b'}
v3 = {'var':dsLRo.nums, 'r':rL_o, 'method':'plot', 'label':'LASER original', 's':8, 'color':'pink', 'linestyle':'dashdot'}
v4 = {'var':dsLRc.nums, 'r':rL_c, 'method':'plot', 'label':'LASER chance'  , 's':7, 'color':'forestgreen', 'linestyle':'dashdot'}
v11 = {'var':dsGRo.nums2, 'r':dsGRo.nums2.sep, 'method':'plot', 'label':'GLAD original', 's':9, 'color':'r', 'linestyle':'solid'}
v22 = {'var':dsGRc.nums2, 'r':dsGRc.nums2.sep, 'method':'plot', 'label':'GLAD chance'  , 's':8, 'color':'b', 'linestyle':'solid'}
v33 = {'var':dsLRo.nums2, 'r':dsLRo.nums2.sep, 'method':'plot', 'label':'LASER original', 's':8, 'color':'pink', 'linestyle':'dashdot'}
v44 = {'var':dsLRc.nums2, 'r':dsLRc.nums2.sep, 'method':'plot', 'label':'LASER chance'  , 's':7, 'color':'forestgreen', 'linestyle':'dashdot'}
v111 = {'var':dsGRo.lvc+1, 'r':rG_o, 'CIs':[dsGRo.CILlv+1, dsGRo.CIUlv+1], 'method':'plot', 'label':'GLAD original', 's':9, 'color':'r', 'lw':1.6}
v222 = {'var':dsGRc.lvc+1, 'r':rG_c, 'CIs':[dsGRc.CILlv+1, dsGRc.CIUlv+1], 'method':'plot', 'label':'GLAD chance'  , 's':8, 'color':'b'}
v333 = {'var':dsLRo.lvc, 'r':rL_o, 'CIs':[dsLRo.CILlv, dsLRo.CIUlv], 'method':'plot', 'label':'LASER original', 's':8, 'color':'pink', 'lw':1.6, 'linestyle':'dashdot'}
v444 = {'var':dsLRc.lvc, 'r':rL_c, 'CIs':[dsLRc.CILlv, dsLRc.CIUlv], 'method':'plot', 'label':'LASER chance'  , 's':7, 'color':'forestgreen', 'linestyle':'dashdot'}
v555 = {'var':dsGRAl.nums_all, 'r':dsGRAl.nums_all.sep, 'method':'plot', 'label':'GLAD all' , 's':8, 'color':'k'}
v666 = {'var':dsLRAl.nums_all, 'r':dsLRAl.nums_all.sep, 'method':'plot', 'label':'LASER all', 's':8, 'color':'k', 'linestyle':'dashdot'}

fig, axes = pplt.subplots(nrows=2, ncols=2, figsize=(7, 5.5), facecolor='w', sharex=0, sharey=0, wspace=3)

ax = panel(axes[0,0], [v1,v2,v3,v4], [], title=f'\t\t\t\t\t\t\t\t\t\t\t\tNo. of pairs (t-based)', timebased=True, thre=30, size=0.9,
           yscale='log', xscale='semilog', ylim=[1e0, 4e3], xlim=[1e-1, 1e2], fontsize=10,
           ylabel='number of pairs', xlabel='\t\t\t\t\t\t\t\t\t\t\t\ttime (day)', loc=None)
ax = panel(axes[0,1], [v11,v22,v33,v44,v555,v666], [], title=f'No. of pairs (r-based)', timebased=False,
           yscale='log', xscale='log', ylim=[1e0, 1e5], xlim=[1e-1, 4e2], fontsize=10,
           ylabel='', xlabel='$r$ (km)', loc=None)
ax[0].plot([50, 50], [1, 1e6], lw=0.6, linestyle='solid', color='purple')
lgd = ax[2]
ax = panel(axes[1,0], [v111,v222,v333,v444], [], title=f'\t\t\t\t\t\t\t\t\t\t\t\tvelocity corr. (t-based)', timebased=True, thre=30, size=0.9,
           yscale='linear', xscale='semilog', ylim=[0, 2.1], xlim=[1e-1, 1e2], rebins=tbins, fontsize=10,
           ylabel='$2<\\mathbf{v}_i\\cdot \\mathbf{v}_j>/(<\\mathbf{v}_i^2>+<\\mathbf{v}_j^2>)$', xlabel='\t\t\t\t\t\t\t\t\t\t\t\ttime (day)', loc=None, ncols=1)
ax[0].text(-100, 1.75, f'GLAD, $r_0=${groupG} km', color='k')
ax[0].text(-100, 0.7, f'LASER, $r_0=${groupL} km', color='k')
ax = panel(axes[1,1], [v111,v222,v333,v444], [], title=f'velocity corr. (r-based)', timebased=False,
           yscale='linear', xscale='log', ylim=[0, 2.1], xlim=[1e-1, 4e2], rebins=sbins, fontsize=10,
           ylabel='', xlabel='$r_{rms}$ (km)', loc=None, ncols=1)
ax[0].text(0.2, 1.65, f'GLAD, $r_0=${groupG} km', color='k')
ax[0].text(0.2, 0.7, f'LASER, $r_0=${groupL} km', color='k')
ax[0].plot([50, 50], [0, 3], lw=0.5, linestyle='solid', color='purple')
lgd = [lgd[0], lgd[1], lgd[4], lgd[2], lgd[3], lgd[5]]
fig.legend(lgd, loc='b', ncols=3)
axes.format(abc='(a)')
#fig.savefig('fig02.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=2, ncols=2, figwidth=7.0, figheight=5.5)

# %%
# initial memory
import proplot as pplt
from xdispersion import panel

vrng = 0.4

# km m/s to km^2/d
v111 = {'var':dsGRo.initm*86.4, 'r':rG_o, 'method':'plot', 'label':'original', 's':9, 'color':'r', 'lw':1.6}
v222 = {'var':dsGRc.initm*86.4, 'r':rG_c, 'method':'plot', 'label':'original+chance' , 's':8, 'color':'b'}
v333 = {'var':dsLRo.initm*86.4, 'r':rL_o, 'method':'plot', 'label':'original', 's':8, 'color':'pink', 'lw':1.6, 'linestyle':'dashdot'}
v444 = {'var':dsLRc.initm*86.4, 'r':rL_c, 'method':'plot', 'label':'original+chance' , 's':7, 'color':'forestgreen', 'linestyle':'dashdot'}

v555 = {'var':dsGRo.aniab, 'r':rG_o, 'method':'plot', 'label':'original', 's':9, 'color':'r', 'lw':1.6}
v666 = {'var':dsGRc.aniab, 'r':rG_c, 'method':'plot', 'label':'original+chance' , 's':8, 'color':'b'}
v777 = {'var':dsLRo.aniab, 'r':rL_o, 'method':'plot', 'label':'original', 's':8, 'color':'pink', 'lw':1.6, 'linestyle':'dashdot'}
v888 = {'var':dsLRc.aniab, 'r':rL_c, 'method':'plot', 'label':'original+chance' , 's':7, 'color':'forestgreen', 'linestyle':'dashdot'}

fig, axes = pplt.subplots(nrows=1, ncols=2, figsize=(7, 2.6), facecolor='w', sharex=0, sharey=0, wspace=4)


ax = panel(axes[0,0], [v111,v222], [], title=f'GLAD initial memory', timebased=False,
           yscale='linear', xscale='log', ylim=[-vrng, vrng], xlim=[1e-1, 1e1], rebins=sbins, fontsize=10,
           ylabel='$<\\mathbf{r}_0\\cdot\\delta \\mathbf{v}>$ ($km^2$ $d^{-1}$)', xlabel='$r_{rms}$ (km)', loc='ll', ncols=1)
ax = panel(axes[0,1], [v333,v444], [], title=f'LASER initial memory', timebased=False,
           yscale='linear', xscale='log', ylim=[-vrng, vrng], xlim=[1e-1, 1e1], rebins=sbins, fontsize=10,
           ylabel='', xlabel='$r_{rms}$ (km)', loc='ll', ncols=1)
#ax = panel(axes[1,0], [v555,v666], [], title=f'GLAD anisotropy', timebased=False,
#           yscale='linear', xscale='log', ylim=[0, 10], xlim=[1e-1, 1e1], rebins=sbins, fontsize=10,
#           ylabel='$(<r_a^2>/<r_b^2>)^{1/2}$', xlabel='$r_{rms}$ (km)', loc='ul', ncols=1)
#ax = panel(axes[1,1], [v777,v888], [], title=f'LASER anisotropy', timebased=False,
#           yscale='linear', xscale='log', ylim=[0, 10], xlim=[1e-1, 1e1], rebins=sbins, fontsize=10,
#           ylabel='', xlabel='$r_{rms}$ (km)', loc='ur', ncols=1)

axes.format(abc='(a)')
#fig.savefig('fig07.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=1, ncols=2, figwidth=7.0, figheight=2.6)

# %%
# RD, K2, Kurtosis, CIST for GLAD original
import proplot as pplt
from xdispersion import panel

sz, lw = 15, 0.6

fig, axes = pplt.subplots(nrows=2, ncols=2, figsize=(7, 5.5), facecolor='w', sharex=0, sharey=0, wspace=5)

offst = 400
params1 = {'T':16, 'beta':0.3, 'k2':450, 'r0':r0_gla, 'lambda':0.29}

def addTexts(ax, x, y, params):
    ax.text(x, y      , f'$T_L={params["T"]}$'            , fontsize=11, color='k')
    ax.text(x, y/1.5e1, f' $\\lambda={params["lambda"]}$' , fontsize=11, color='azure')
    ax.text(x, y/3e2  , f'  $\\beta={params["beta"]}$'    , fontsize=11, color='b')
    ax.text(x, y/4.5e3, f'$\\kappa_2={params["k2"]}$'     , fontsize=11, color='darkgreen')

r2_lund1 = rd.analytic_r2(rG_o, params1, 'Lundgren')
r2_Rich1 = rd.analytic_r2(rG_o, params1, 'Richardson')
r2_Rayl1 = rd.analytic_r2(rG_o, params1, 'Rayleigh')
r2_GM1   = rd.analytic_r2(rG_o, params1, '-2')
K2_lund1 = rd.analytic_K2(rG_o, params1, 'Lundgren')
K2_Rich1 = rd.analytic_K2(rG_o, params1, 'Richardson')
K2_Rayl1 = rd.analytic_K2(rG_o, params1, 'Rayleigh')
K2_GM1   = rd.analytic_K2(rG_o, params1, '-2')
Ku_lund1 = rd.analytic_Kurtosis(rG_o, params1, 'Lundgren')
Ku_Rich1 = rd.analytic_Kurtosis(rG_o, params1, 'Richardson')
Ku_Rayl1 = rd.analytic_Kurtosis(rG_o, params1, 'Rayleigh')
Ku_GM1   = rd.analytic_Kurtosis(rG_o, params1, '-2')
ci_lund1 = rd.analytic_CIST(dsGRo.r, alpha, params1, 'Lundgren')
ci_Rich1 = rd.analytic_CIST(dsGRo.r, alpha, params1, 'Richardson-a')
ci_Rayl1 = rd.analytic_CIST(dsGRo.r, alpha, params1, 'Rayleigh-a')
ci_GM1   = rd.analytic_CIST(dsGRo.r, alpha, params1, '-2-a')

v111 = {'var':dsGRo.r2, 'r':rG_o, 'CIs':[dsGRo.CILr, dsGRo.CIUr], 'method':'scatter', 'label':'GLAD dataset', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v115 = {'var':r2_lund1[300:1600]*offst, 'r':rG_o[300:1600], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v116 = {'var':r2_Rich1[:2200], 'r':rG_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v117 = {'var':r2_Rayl1[2400:], 'r':rG_o[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v118 = {'var':r2_GM1[:2200]  , 'r':rG_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

v121 = {'var':dsGRo.Ku, 'r':rG_o, 'CIs':[dsGRo.CILKu, dsGRo.CIUKu], 'method':'scatter', 'label':'GLAD dataset', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v125 = {'var':Ku_lund1[:900] , 'r':rG_o[:900] , 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v126 = {'var':Ku_Rich1[:2200], 'r':rG_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v127 = {'var':Ku_Rayl1[2400:], 'r':rG_o[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v128 = {'var':Ku_GM1[:2200]  , 'r':rG_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILK2_o1, RCIUK2_o1 = dsGRo.CILK2t.where(dsGRo.CILK2t>0).interpolate_na('time'), dsGRo.CIUK2t.where(dsGRo.CIUK2t>0).interpolate_na('time')

v131 = {'var':dsGRo.K2t, 'r':rG_o, 'CIs':[RCILK2_o1, RCIUK2_o1], 'method':'scatter', 'label':'GLAD dataset', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v135 = {'var':K2_lund1[360:1800], 'r':rG_o[360:1800], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v136 = {'var':K2_Rich1[:1200], 'r':rG_o[:1200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v137 = {'var':K2_Rayl1[1200:], 'r':rG_o[1200:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v138 = {'var':K2_GM1[:1200]  , 'r':rG_o[:1200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILci_o1, RCIUci_o1 = dsGRo.CILci, dsGRo.CIUci

v141 = {'var':dsGRo.cist1, 'r':dsGRo.r, 'CIs':[RCILci_o1, RCIUci_o1], 'method':'scatter', 'label':'GLAD original', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v145 = {'var':ci_lund1[19:34], 'r':dsGRo.r[19:34], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v146 = {'var':ci_Rich1[:37]  , 'r':dsGRo.r[:37]  , 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v147 = {'var':ci_Rayl1[35:]  , 'r':dsGRo.r[35:]  , 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v148 = {'var':ci_GM1[:37]    , 'r':dsGRo.r[:37]  , 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

ax = panel(axes[0,0], [v111], [v115,v118,v116,v117], title=' \t\t\t\t\t\t\t\t\t GLAD relative disp.', timebased=True, yscale='log', xscale='semilog',
           ylim=[1e-2, 4e5], xlim=[1e-2, 95], rebins=tbins, ylabel='$<r^2>$ ($km^2$)', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
addTexts(ax[1], 30, 3e2, params1)
ax[1].text(-108, 1700, '——————————————————————', color='purple')
ax[0].plot([-100, 1e3], [2500, 2500], lw=0.5, linestyle='solid', color='purple', zorder=5)
ax = panel(axes[0,1], [v121], [v125,v128,v126,v127], title=' \t\t\t\t\t\t\t\t\t\t GLAD Kurtosis', timebased=True, yscale='linear', xscale='semilog',
           ylim=[8e-1, 60], xlim=[1e-2, 95], rebins=tbins, ylabel='$<r^4>/<r^2>^2$', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
ax = panel(axes[1,0], [v131], [v135,v138,v136,v137], title=f'GLAD dispersion diffusivity', timebased=False, yscale='log', xscale='log',
           ylim=[1e-2, 1e4], xlim=[1e-1, 5e2], rebins=sbins, ylabel='$d<r^2>/dt/2$ ($km^2$ $d^{-1}$)', xlabel='$r_{rms}$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 1e4], lw=0.5, linestyle='solid', color='purple')
ax = panel(axes[1,1], [v141], [v145,v148,v146,v147], title=f'GLAD CIST', timebased=False, yscale='log', xscale='log',
           ylim=[1e-3, 3e1], xlim=[1e-1, 5e2], ylabel='CIST ($d^{-1}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 2e2], lw=0.5, linestyle='solid', color='purple')
lgd = ax[2]
fig.legend(lgd, loc='b', ncols=5)
axes.format(abc='(a)')
#fig.savefig('fig03.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=2, ncols=2, figwidth=7.0, figheight=5.5)

# %%
# RD, K2, Kurtosis, CIST for GLAD chance
import proplot as pplt
from xdispersion import panel

sz, lw = 15, 0.6

fig, axes = pplt.subplots(nrows=2, ncols=2, figsize=(7, 5.5), facecolor='w', sharex=0, sharey=0, wspace=5)

offst = 2300
#params1 = {'T':16.5, 'beta':0.75, 'k2':950, 'r0':r0_gla, 'lambda':0.55}
params1 = {'T':16.5, 'beta':0.6, 'k2':650, 'r0':r0_gla, 'lambda':0.45}

def addTexts(ax, x, y, params):
    ax.text(x, y      , f'$T_L={params["T"]}$'            , fontsize=11, color='k')
    ax.text(x, y/1.5e1, f' $\\lambda={params["lambda"]}$' , fontsize=11, color='azure')
    ax.text(x, y/3e2  , f'  $\\beta={params["beta"]}$'    , fontsize=11, color='b')
    ax.text(x, y/4.5e3, f'$\\kappa_2={params["k2"]}$'     , fontsize=11, color='darkgreen')

r2_lund1 = rd.analytic_r2(rG_c, params1, 'Lundgren')
r2_Rich1 = rd.analytic_r2(rG_c, params1, 'Richardson')
r2_Rayl1 = rd.analytic_r2(rG_c, params1, 'Rayleigh')
r2_GM1   = rd.analytic_r2(rG_c, params1, '-2')
K2_lund1 = rd.analytic_K2(rG_c, params1, 'Lundgren')
K2_Rich1 = rd.analytic_K2(rG_c, params1, 'Richardson')
K2_Rayl1 = rd.analytic_K2(rG_c, params1, 'Rayleigh')
K2_GM1   = rd.analytic_K2(rG_c, params1, '-2')
Ku_lund1 = rd.analytic_Kurtosis(rG_c, params1, 'Lundgren')
Ku_Rich1 = rd.analytic_Kurtosis(rG_c, params1, 'Richardson')
Ku_Rayl1 = rd.analytic_Kurtosis(rG_c, params1, 'Rayleigh')
Ku_GM1   = rd.analytic_Kurtosis(rG_c, params1, '-2')
ci_lund1 = rd.analytic_CIST(dsGRc.r, alpha, params1, 'Lundgren')
ci_Rich1 = rd.analytic_CIST(dsGRc.r, alpha, params1, 'Richardson-a')
ci_Rayl1 = rd.analytic_CIST(dsGRc.r, alpha, params1, 'Rayleigh-a')
ci_GM1   = rd.analytic_CIST(dsGRc.r, alpha, params1, '-2-a')

v111 = {'var':dsGRc.r2, 'r':rG_c, 'CIs':[dsGRc.CILr, dsGRc.CIUr], 'method':'scatter', 'label':'GLAD dataset', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v115 = {'var':r2_lund1[200:1400]*offst, 'r':rG_c[200:1400], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v116 = {'var':r2_Rich1[:2200], 'r':rG_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v117 = {'var':r2_Rayl1[2400:], 'r':rG_c[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v118 = {'var':r2_GM1[:2200]  , 'r':rG_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

v121 = {'var':dsGRc.Ku, 'r':rG_c, 'CIs':[dsGRc.CILKu, dsGRc.CIUKu], 'method':'scatter', 'label':'GLAD dataset', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v125 = {'var':Ku_lund1[:1500] , 'r':rG_c[:1500] , 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v126 = {'var':Ku_Rich1[:2200], 'r':rG_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v127 = {'var':Ku_Rayl1[2400:], 'r':rG_c[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v128 = {'var':Ku_GM1[:2200]  , 'r':rG_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILK2_c1, RCIUK2_c1 = dsGRc.CILK2t.where(dsGRc.CILK2t>0).interpolate_na('time'), dsGRc.CIUK2t.where(dsGRc.CIUK2t>0).interpolate_na('time')

v131 = {'var':dsGRc.K2t, 'r':rG_c, 'CIs':[RCILK2_c1, RCIUK2_c1], 'method':'scatter', 'label':'GLAD dataset', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v135 = {'var':K2_lund1[300:1300], 'r':rG_c[300:1300], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v136 = {'var':K2_Rich1[:1250], 'r':rG_c[:1250], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v137 = {'var':K2_Rayl1[1200:], 'r':rG_c[1200:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v138 = {'var':K2_GM1[:1250]  , 'r':rG_c[:1250], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILci_c1, RCIUci_c1 = dsGRc.CILci, dsGRc.CIUci

v141 = {'var':dsGRc.cist1, 'r':dsGRc.r, 'CIs':[RCILci_c1, RCIUci_c1], 'method':'scatter', 'label':'GLAD origin+chance', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v145 = {'var':ci_lund1[25:43], 'r':dsGRc.r[25:43], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v146 = {'var':ci_Rich1[:37]  , 'r':dsGRc.r[:37]  , 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v147 = {'var':ci_Rayl1[35:]  , 'r':dsGRc.r[35:]  , 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'g'}
v148 = {'var':ci_GM1[:37]    , 'r':dsGRc.r[:37]  , 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

ax = panel(axes[0,0], [v111], [v115,v118,v116,v117], title=' \t\t\t\t\t\t\t\t\t GLAD relative disp.', timebased=True, yscale='log', xscale='semilog',
           ylim=[1e-2, 4e5], xlim=[1e-2, 95], rebins=tbins, ylabel='$<r^2>$ ($km^2$)', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
addTexts(ax[1], 30, 3e2, params1)
ax[1].text(-108, 1700, '——————————————————————', color='purple')
ax[0].plot([-100, 1e3], [2500, 2500], lw=0.5, linestyle='solid', color='purple', zorder=5)
ax = panel(axes[0,1], [v121], [v125,v128,v126,v127], title=' \t\t\t\t\t\t\t\t\t\t GLAD Kurtosis', timebased=True, yscale='linear', xscale='semilog',
           ylim=[8e-1, 60], xlim=[1e-2, 95], rebins=tbins, ylabel='$<r^4>/<r^2>^2$', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
ax = panel(axes[1,0], [v131], [v135,v138,v136,v137], title=f'GLAD dispersion diffusivity', timebased=False, yscale='log', xscale='log',
           ylim=[3e-2, 1e4], xlim=[1e-1, 5e2], rebins=sbins, ylabel='$d<r^2>/dt/2$ ($km^2$ $d^{-1}$)', xlabel='$r_{rms}$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 1e4], lw=0.5, linestyle='solid', color='purple')
ax = panel(axes[1,1], [v141], [v145,v148,v146,v147], title=f'GLAD CIST', timebased=False, yscale='log', xscale='log',
           ylim=[1e-3, 5e1], xlim=[1e-1, 5e2], ylabel='CIST ($d^{-1}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 2e2], lw=0.5, linestyle='solid', color='purple')
lgd = ax[2]
fig.legend(lgd, loc='b', ncols=5)
axes.format(abc='(a)')
#fig.savefig('fig05.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=2, ncols=2, figwidth=7.0, figheight=5.5)

# %%
# S2, S3, FSLE for GLAD
import proplot as pplt
from xdispersion import panel

unitscale2 = (86.4)**2.0
unitscale3 = (86.4)**3.0
sz, lw = 15, 0.6

vS3G1p = {'var': dsGRo.S3r.where(dsGRo.S3r>0)*unitscale3, 'r':dsGRo.sep , 'method':'scatter', 'label':'original (positive)', 's':sz, 'lw':lw, 'color':'r'}
vS3G2p = {'var': dsGRc.S3r.where(dsGRc.S3r>0)*unitscale3, 'r':dsGRc.sep , 'method':'scatter', 'label':'original+chance (positive)'  , 's':sz+1, 'lw':lw, 'color':'forestgreen', 'marker':'x'}
vS3G3p = {'var': dsGRAl.S3.where(dsGRAl.S3>0)*unitscale3/100, 'r':dsGRAl.sep, 'method':'scatter', 'label':'all possible (positive)', 's':sz, 'lw':lw, 'color':'gray'}
vS3G1n = {'var': -dsGRo.S3r.where(dsGRo.S3r<0)*unitscale3, 'r':dsGRo.sep , 'method':'scatter', 'label':'original (negative)', 's':sz, 'lw':lw, 'edgecolor':'r', 'facecolor':'white'}
vS3G2n = {'var': -dsGRc.S3r.where(dsGRc.S3r<0)*unitscale3, 'r':dsGRc.sep , 'method':'scatter', 'label':'original+chance (negative)'  , 's':sz+2, 'lw':lw, 'color':'forestgreen', 'marker':'*'}
vS3G3n = {'var': -dsGRAl.S3.where(dsGRo.S3r<0)*unitscale3/100, 'r':dsGRAl.sep, 'method':'scatter', 'label':'all possible (negative)', 's':sz, 'lw':lw, 'facecolor':'white', 'edgecolor':'gray'}
vS3G5 = {'var': dsGRAl.sep[:35]**1.5*3e1, 'r':dsGRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'color':'azure', 'linestyle':'solid'}
vS3G6 = {'var': dsGRAl.sep[:35]**1.0*2e1, 'r':dsGRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'color':'b', 'linestyle':'dashed'}
vS3G55= {'var': dsGRAl.sep[:35]**1.5*4e1/100, 'r':dsGRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'color':'azure', 'linestyle':'solid'}
vS3G66= {'var': dsGRAl.sep[:35]**1.0*3e1/100, 'r':dsGRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'color':'b', 'linestyle':'dashed'}


vS3L1p = {'var': dsLRo.S3r.where(dsLRo.S3r>0)*unitscale3, 'r':dsLRo.sep , 'method':'scatter', 'label':'LASER original', 's':sz, 'lw':lw, 'color':'r'}
vS3L2p = {'var': dsLRc.S3r.where(dsLRc.S3r>0)*unitscale3, 'r':dsLRc.sep , 'method':'scatter', 'label':'LASER chance'  , 's':sz+1, 'lw':lw, 'color':'forestgreen', 'marker':'x'}
vS3L3p = {'var': dsLRAl.S3.where(dsLRAl.S3>0)*unitscale3/100, 'r':dsLRAl.sep, 'method':'scatter', 'label':'LASER all', 's':sz, 'lw':lw, 'color':'gray'}
vS3L1n = {'var': -dsLRo.S3r.where(dsLRo.S3r<0)*unitscale3, 'r':dsLRo.sep , 'method':'scatter', 'label':'LASER original', 's':sz, 'lw':lw, 'edgecolor':'r', 'facecolor':'white'}
vS3L2n = {'var': -dsLRc.S3r.where(dsLRc.S3r<0)*unitscale3, 'r':dsLRc.sep , 'method':'scatter', 'label':'LASER chance'  , 's':sz+2, 'lw':lw, 'color':'forestgreen', 'marker':'*'}
vS3L3n = {'var': -dsLRAl.S3.where(dsLRAl.S3<0)*unitscale3/100, 'r':dsLRAl.sep, 'method':'scatter', 'label':'LASER all', 's':sz, 'lw':lw, 'facecolor':'white', 'edgecolor':'gray'}
vS3L5 = {'var': dsLRAl.sep[:35]**1.5*3e1, 'r':dsLRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'color':'azure', 'linestyle':'solid'}
vS3L6 = {'var': dsLRAl.sep[:35]**1.0*2e1, 'r':dsLRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'color':'b', 'linestyle':'dashed'}
vS3L55= {'var': dsLRAl.sep[:35]**1.5*10e1/100, 'r':dsLRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'color':'azure', 'linestyle':'solid'}
vS3L66= {'var': dsLRAl.sep[:35]**1.0*4e1/100, 'r':dsLRAl.sep[:35], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'color':'b', 'linestyle':'dashed'}

fig, axes = pplt.subplots(nrows=1, ncols=2, figsize=(8, 4), facecolor='w', sharex=0, sharey=1, wspace=5.4)

ax = panel(axes[0], [vS3G1p,vS3G3p, vS3G1n,vS3G3n], [vS3G5,vS3G6,vS3G55,vS3G66], title=f'GLAD $S_3$',
           timebased=False, yscale='log', xscale='log', ylim=[1e-2, 2e5], xlim=[1e-1, 6e2], rebins=sbins,
           ylabel='$<\\mathbf{v}_i - \\mathbf{v}_j>^3$ ($km^3$ $d^{-3}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [0, 3e5], lw=0.5, linestyle='solid', color='purple')
ax[0].text(0.15, 600, '($r_0=$0.13 km)', fontsize=10)
ax[0].text(50, 3, '(all pairs)', fontsize=10)
lgd = ax[2]
lgd = [lgd[0], lgd[1], lgd[6], lgd[2], lgd[3], lgd[5]]
ax = panel(axes[1], [vS3L1p,vS3L3p, vS3L1n,vS3L3n], [vS3L5,vS3L6,vS3L55,vS3L66], title=f'LASER $S_3$',
           timebased=False, yscale='log', xscale='log', ylim=[1e-2, 2e5], xlim=[1e-1, 6e2], rebins=sbins,
           ylabel='', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [0, 3e5], lw=0.5, linestyle='solid', color='purple')
ax[0].text(0.15, 600, '($r_0=$0.2 km)', fontsize=10)
ax[0].text(50, 3, '(all pairs)', fontsize=10)
fig.legend(lgd, loc='b', ncols=3)
axes.format(abc='(a)')
#fig.savefig('fig09.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=1, ncols=2, figwidth=8.0, figheight=4.0)

# %%
# RD, K2, Kurtosis, CIST for LASER original
import proplot as pplt
from xdispersion import panel

sz, lw = 15, 0.6

fig, axes = pplt.subplots(nrows=2, ncols=2, figsize=(6.6, 5.5), facecolor='w', sharex=0, sharey=0, wspace=5)

offst = 18
params1 = {'T':5.7, 'beta':0.5, 'k2':500, 'r0':r0_las, 'lambda':0.45}

def addTexts(ax, x, y, params):
    ax.text(x, y      , f'$T_L={params["T"]}$'            , fontsize=11, color='k')
    ax.text(x, y/1.5e1, f' $\\lambda={params["lambda"]}$' , fontsize=11, color='azure')
    ax.text(x, y/3e2  , f'  $\\beta={params["beta"]}$'    , fontsize=11, color='b')
    ax.text(x, y/4.5e3, f'$\\kappa_2={params["k2"]}$'     , fontsize=11, color='darkgreen')

r2_lund1 = rd.analytic_r2(rL_o, params1, 'Lundgren')
r2_Rich1 = rd.analytic_r2(rL_o, params1, 'Richardson')
r2_Rayl1 = rd.analytic_r2(rL_o, params1, 'Rayleigh')
r2_GM1   = rd.analytic_r2(rL_o, params1, '-2')
K2_lund1 = rd.analytic_K2(rL_o, params1, 'Lundgren')
K2_Rich1 = rd.analytic_K2(rL_o, params1, 'Richardson')
K2_Rayl1 = rd.analytic_K2(rL_o, params1, 'Rayleigh')
K2_GM1   = rd.analytic_K2(rL_o, params1, '-2')
Ku_lund1 = rd.analytic_Kurtosis(rL_o, params1, 'Lundgren')
Ku_Rich1 = rd.analytic_Kurtosis(rL_o, params1, 'Richardson')
Ku_Rayl1 = rd.analytic_Kurtosis(rL_o, params1, 'Rayleigh')
Ku_GM1   = rd.analytic_Kurtosis(rL_o, params1, '-2')
ci_lund1 = rd.analytic_CIST(dsLRo.r, alpha, params1, 'Lundgren')
ci_Rich1 = rd.analytic_CIST(dsLRo.r, alpha, params1, 'Richardson-a')
ci_Rayl1 = rd.analytic_CIST(dsLRo.r, alpha, params1, 'Rayleigh-a')
ci_GM1   = rd.analytic_CIST(dsLRo.r, alpha, params1, '-2-a')

v111 = {'var':dsLRo.r2, 'r':rL_o, 'CIs':[dsLRo.CILr, dsLRo.CIUr], 'method':'scatter', 'label':'LASER original', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v115 = {'var':r2_lund1[140:700]*offst, 'r':rL_o[140:700], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v116 = {'var':r2_Rich1[:2200], 'r':rL_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v117 = {'var':r2_Rayl1[2400:], 'r':rL_o[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v118 = {'var':r2_GM1[:2200]  , 'r':rL_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

v121 = {'var':dsLRo.Ku, 'r':rL_o, 'CIs':[dsLRo.CILKu, dsLRo.CIUKu], 'method':'scatter', 'label':'LASER original', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v125 = {'var':Ku_lund1[:900] , 'r':rL_o[:900] , 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v126 = {'var':Ku_Rich1[:2200], 'r':rL_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v127 = {'var':Ku_Rayl1[2400:], 'r':rL_o[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v128 = {'var':Ku_GM1[:2200]  , 'r':rL_o[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILK2_o1, RCIUK2_o1 = dsLRo.CILK2t.where(dsLRo.CILK2t>0).interpolate_na('time'), dsLRo.CIUK2t.where(dsLRo.CIUK2t>0).interpolate_na('time')

v131 = {'var':dsLRo.K2t, 'r':rL_o, 'CIs':[RCILK2_o1, RCIUK2_o1], 'method':'scatter', 'label':'LASER original', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v135 = {'var':K2_lund1[30:450], 'r':rL_o[30:450], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v136 = {'var':K2_Rich1[:1200], 'r':rL_o[:1200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v137 = {'var':K2_Rayl1[1000:], 'r':rL_o[1000:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v138 = {'var':K2_GM1[:1200]  , 'r':rL_o[:1200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILci_o1, RCIUci_o1 = dsLRo.CILci, dsLRo.CIUci

v141 = {'var':dsLRo.cist1, 'r':dsLRo.r, 'CIs':[RCILci_o1, RCIUci_o1], 'method':'scatter', 'label':'LASER original', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v145 = {'var':ci_lund1[8:30], 'r':dsLRo.r[8:30], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v146 = {'var':ci_Rich1[:36]  , 'r':dsLRo.r[:36]  , 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v147 = {'var':ci_Rayl1[35:]  , 'r':dsLRo.r[35:]  , 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v148 = {'var':ci_GM1[:36]    , 'r':dsLRo.r[:36]  , 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

ax = panel(axes[0,0], [v111], [v115,v118,v116,v117], title=' \t\t\t\t\t\t\t\t\t LASER relative disp.', timebased=True, yscale='log', xscale='semilog',
           ylim=[1e-2, 4e5], xlim=[1e-2, 80], rebins=tbins, ylabel='$<r^2>$ ($km^2$)', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
addTexts(ax[1], 30, 3e2, params1)
ax[1].text(-66, 1700, '—————————————————————', color='purple')
ax[0].plot([-100, 1e3], [2500, 2500], lw=0.5, linestyle='solid', color='purple', zorder=5)
ax = panel(axes[0,1], [v121], [v125,v128,v126,v127], title=' \t\t\t\t\t\t\t\t\t\t LASER Kurtosis', timebased=True, yscale='linear', xscale='semilog',
           ylim=[8e-1, 25], xlim=[1e-2, 80], rebins=tbins, ylabel='$<r^4>/<r^2>^2$', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
ax = panel(axes[1,0], [v131], [v135,v138,v136,v137], title=f'LASER relative diffusivity', timebased=False, yscale='log', xscale='log',
           ylim=[3e-2, 1e4], xlim=[1e-1, 5e2], rebins=sbins, ylabel='$d<r^2>/dt/2$ ($km^2$ $d^{-1}$)', xlabel='$r_{rms}$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 1e4], lw=0.5, linestyle='solid', color='purple')
ax = panel(axes[1,1], [v141], [v145,v148,v146,v147], title=f'LASER CIST', timebased=False, yscale='log', xscale='log',
           ylim=[3e-3, 4e1], xlim=[1e-1, 5e2], ylabel='CIST ($d^{-1}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 1e2], lw=0.5, linestyle='solid', color='purple')
lgd = ax[2]
fig.legend(lgd, loc='b', ncols=5)
axes.format(abc='(a)')
#fig.savefig('fig04.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=2, ncols=2, figwidth=6.6, figheight=5.5)

# %%
# RD, K2, Kurtosis, CIST for LASER chance
import proplot as pplt
from xdispersion import panel

sz, lw = 15, 0.6

fig, axes = pplt.subplots(nrows=2, ncols=2, figsize=(6.6, 5.5), facecolor='w', sharex=0, sharey=0, wspace=5)

offst = 18
params1 = {'T':0.33, 'beta':0.9, 'k2':1000, 'r0':r0_las, 'lambda':0.6}

def addTexts(ax, x, y, params):
    ax.text(x, y      , f'$T_L={params["T"]}$'            , fontsize=11, color='k')
    ax.text(x, y/1.5e1, f' $\\lambda={params["lambda"]}$' , fontsize=11, color='azure')
    ax.text(x, y/3e2  , f'  $\\beta={params["beta"]}$'    , fontsize=11, color='b')
    ax.text(x, y/4.5e3, f'$\\kappa_2={params["k2"]}$'     , fontsize=11, color='darkgreen')

r2_lund1 = rd.analytic_r2(rL_c, params1, 'Lundgren')
r2_Rich1 = rd.analytic_r2(rL_c, params1, 'Richardson')
r2_Rayl1 = rd.analytic_r2(rL_c, params1, 'Rayleigh')
r2_GM1   = rd.analytic_r2(rL_c, params1, '-2')
K2_lund1 = rd.analytic_K2(rL_c, params1, 'Lundgren')
K2_Rich1 = rd.analytic_K2(rL_c, params1, 'Richardson')
K2_Rayl1 = rd.analytic_K2(rL_c, params1, 'Rayleigh')
K2_GM1   = rd.analytic_K2(rL_c, params1, '-2')
Ku_lund1 = rd.analytic_Kurtosis(rL_c, params1, 'Lundgren')
Ku_Rich1 = rd.analytic_Kurtosis(rL_c, params1, 'Richardson')
Ku_Rayl1 = rd.analytic_Kurtosis(rL_c, params1, 'Rayleigh')
Ku_GM1   = rd.analytic_Kurtosis(rL_c, params1, '-2')
ci_lund1 = rd.analytic_CIST(dsLRc.r, alpha, params1, 'Lundgren')
ci_Rich1 = rd.analytic_CIST(dsLRc.r, alpha, params1, 'Richardson-a')
ci_Rayl1 = rd.analytic_CIST(dsLRc.r, alpha, params1, 'Rayleigh-a')
ci_GM1   = rd.analytic_CIST(dsLRc.r, alpha, params1, '-2-a')

v112 = {'var':dsLRc.r2, 'r':rL_c, 'CIs':[dsLRc.CILr, dsLRc.CIUr], 'method':'scatter', 'label':'LASER chance', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v115 = {'var':r2_lund1[:300], 'r':rL_c[:300], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v116 = {'var':r2_Rich1[:2200], 'r':rL_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v117 = {'var':r2_Rayl1[2400:], 'r':rL_c[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v118 = {'var':r2_GM1[:2200]  , 'r':rL_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

v122 = {'var':dsLRc.Ku, 'r':rL_c, 'CIs':[dsLRc.CILKu, dsLRc.CIUKu], 'method':'scatter', 'label':'LASER chance', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v125 = {'var':Ku_lund1[:900] , 'r':rL_c[:900] , 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v126 = {'var':Ku_Rich1[:2200], 'r':rL_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v127 = {'var':Ku_Rayl1[2400:], 'r':rL_c[2400:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v128 = {'var':Ku_GM1[:2200]  , 'r':rL_c[:2200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILK2_c1, RCIUK2_c1 = dsLRc.CILK2t.where(dsLRc.CILK2t>0).interpolate_na('time'), dsLRc.CIUK2t.where(dsLRc.CIUK2t>0).interpolate_na('time')

v132 = {'var':dsLRc.K2t, 'r':rL_c, 'CIs':[RCILK2_c1, RCIUK2_c1], 'method':'scatter', 'label':'LASER chance', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v135 = {'var':K2_lund1[:200], 'r':rL_c[:200], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
v136 = {'var':K2_Rich1[:1200], 'r':rL_c[:1200], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v137 = {'var':K2_Rayl1[1200:], 'r':rL_c[1200:], 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v138 = {'var':K2_GM1[:1200]  , 'r':rL_c[:1200], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

RCILci_c1, RCIUci_c1 = dsLRc.CILci, dsLRc.CIUci

v142 = {'var':dsLRc.cist1, 'r':dsLRc.r, 'CIs':[RCILci_c1, RCIUci_c1], 'method':'scatter', 'label':'LASER origin + chance', 'lw':lw, 's':sz, 'edgecolor':'r', 'facecolor':'none'}
v145 = {'var':ci_lund1[:10], 'r':dsLRc.r[:10], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$'  , 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
v146 = {'var':ci_Rich1[:40]  , 'r':dsLRc.r[:40]  , 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
v147 = {'var':ci_Rayl1[40:]  , 'r':dsLRc.r[40:]  , 'method':'plot', 'label':'diffusive'  , 'lw':1.4, 'linestyle':'dashdot', 'color':'darkgreen'}
v148 = {'var':ci_GM1[:40]    , 'r':dsLRc.r[:40]  , 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.4, 'linestyle':'solid', 'color':'azure'}

ax = panel(axes[0,0], [v112], [v115,v118,v116,v117], title=' \t\t\t\t\t\t\t\t\t LASER relative disp.', timebased=True, yscale='log', xscale='semilog',
           ylim=[1e-2, 9e5], xlim=[1e-2, 80], rebins=tbins, ylabel='$<r^2>$ ($km^2$)', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
addTexts(ax[1], 30, 3e2, params1)
ax[1].text(-66, 1690, '—————————————————————', color='purple')
ax[0].plot([-100, 1e3], [2500, 2500], lw=0.5, linestyle='solid', color='purple', zorder=5)
ax = panel(axes[0,1], [v122], [v125,v128,v126,v127], title=' \t\t\t\t\t\t\t\t\t\t LASER Kurtosis', timebased=True, yscale='linear', xscale='semilog',
           ylim=[8e-1, 70], xlim=[1e-2, 80], rebins=tbins, ylabel='$<r^4>/<r^2>^2$', xlabel='                $time$ (day)', loc=None, fontsize=10, thre=30, size=0.9)
ax = panel(axes[1,0], [v132], [v135,v138,v136,v137], title=f'LASER relative diffusivity', timebased=False, yscale='log', xscale='log',
           ylim=[9e-2, 2e4], xlim=[1e-1, 5e2], rebins=sbins, ylabel='$d<r^2>/dt/2$ ($km^2$ $d^{-1}$)', xlabel='$r_{rms}$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 5e4], lw=0.5, linestyle='solid', color='purple')
ax = panel(axes[1,1], [v142], [v145,v148,v146,v147], title=f'LASER CIST', timebased=False, yscale='log', xscale='log',
           ylim=[1e-3, 1e2], xlim=[1e-1, 5e2], ylabel='CIST ($d^{-1}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [1e-5, 1e2], lw=0.5, linestyle='solid', color='purple')
lgd = ax[2]
fig.legend(lgd, loc='b', ncols=5)
axes.format(abc='(a)')
#fig.savefig('fig06.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=2, ncols=2, figwidth=6.6, figheight=5.5)

# %%
# S2, S3, FSLE for both GLAD and LASER
import proplot as pplt
from xdispersion import panel

unitscale2 = (86.4)**2.0
unitscale3 = (86.4)**3.0
sz, lw = 15, 0.6

S2G_lunda1 = rd.analytic_S2(rG_o, {'T': 0.7}, 'Lundgren')
S2G_Richa1 = rd.analytic_S2(rG_o, {'beta': 6.6}, 'Richardson')
S2G_Rayla1 = rd.analytic_S2(rG_o, {'k2'  :1800}, 'Rayleigh')
S2G_GM1    = rd.analytic_S2(rG_o, {'lambda': 14}, '-2')
vS2G1 = {'var':dsGRo.S2r*unitscale2, 'r':dsGRo.sep, 'CIs':[dsGRo.CILS2r*unitscale2, dsGRo.CIUS2r*unitscale2], 'method':'scatter', 'label':'original', 's':sz, 'lw':lw, 'color':'r'}
vS2G2 = {'var':dsGRc.S2r*unitscale2, 'r':dsGRc.sep, 'CIs':[dsGRc.CILS2r*unitscale2, dsGRc.CIUS2r*unitscale2], 'method':'scatter', 'label':'original+chance'  , 's':sz, 'lw':lw, 'color':'forestgreen', 'marker':'x'}
vS2G3 = {'var':dsGRAl.S2*unitscale2/100, 'r':dsGRAl.sep, 'method':'scatter', 'label':'all possible', 's':sz, 'lw':lw, 'color':'gray', 'marker':'o'}
vS2G4 = {'var':S2G_lunda1[250:1000] , 'r':rG_o[250:1000], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
vS2G5 = {'var':S2G_Richa1[:900] *2.4, 'r':rG_o[:900], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vS2G6 = {'var':S2G_Rayla1[1580:]    , 'r':rG_o[1580:], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vS2G7 = {'var':S2G_GM1[:850]    *1.8, 'r':rG_o[:850], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid' , 'color':'azure'}
vS2G55= {'var':S2G_Richa1[:900] *3.5/100, 'r':rG_o[:900], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vS2G66= {'var':S2G_Rayla1[1580:]    /100, 'r':rG_o[1580:], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vS2G77= {'var':S2G_GM1[:850]    *2.5/100, 'r':rG_o[:850], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid' , 'color':'azure'}

fsleG_lunda = rd.analytic_CIST(dsGRAl.sep, alpha, {'T': 11}, 'Lundgren')
fsleG_Richa = rd.analytic_CIST(dsGRAl.sep, alpha, {'beta': 0.23}, 'Richardson-a')
fsleG_Rayla = rd.analytic_CIST(dsGRAl.sep, alpha, {'k2': 1800}, 'Rayleigh-a')
fsleG_GM    = rd.analytic_CIST(dsGRAl.sep, alpha, {'lambda': 0.5}, '-2-a')
vFG1 = {'var':dsGRo.FSLE     , 'r':dsGRo.sep , 'CIs':[dsGRo.CILFSLE, dsGRo.CIUFSLE], 'method':'scatter', 'label':'original', 's':sz, 'lw':lw, 'color':'r'}
vFG2 = {'var':dsGRc.FSLE     , 'r':dsGRo.sep , 'CIs':[dsGRc.CILFSLE, dsGRc.CIUFSLE], 'method':'scatter', 'label':'original+chance', 's':sz, 'lw':lw, 'color':'forestgreen', 'marker':'x'}
vFG3 = {'var':dsGRAl.FSLE_all/100, 'r':dsGRAl.sep, 'method':'scatter', 'label':'all possible', 's':sz, 'lw':lw, 'color':'gray', 'marker':'o'}
vFG4 = {'var':fsleG_lunda[23:37],'r':dsGRAl.sep[23:37], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
vFG5 = {'var':fsleG_Richa[:-16]*1.1, 'r':dsGRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vFG6 = {'var':fsleG_Rayla[35: ]*1.3, 'r':dsGRAl.sep[35: ], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vFG7 = {'var':fsleG_GM[:-16]   *0.8, 'r':dsGRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid', 'color':'azure'}
vFG55= {'var':fsleG_Richa[:-16]*1.1/100, 'r':dsGRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vFG66= {'var':fsleG_Rayla[35: ]*1.3/100, 'r':dsGRAl.sep[35: ], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vFG77= {'var':fsleG_GM[:-16]   *0.8/100, 'r':dsGRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid', 'color':'azure'}

S2L_lunda1 = rd.analytic_S2(dsLRo.sep, {'T': 0.7}, 'Lundgren')
S2L_Richa1 = rd.analytic_S2(dsLRo.sep, {'beta': 6.6}, 'Richardson')
S2L_Rayla1 = rd.analytic_S2(dsLRo.sep, {'k2'  :1800}, 'Rayleigh')
S2L_GM1    = rd.analytic_S2(dsLRo.sep, {'lambda': 14}, '-2')
vS2L1 = {'var':dsLRo.S2r*unitscale2, 'r':dsLRo.sep, 'CIs':[dsLRo.CILS2r*unitscale2, dsLRo.CIUS2r*unitscale2], 'method':'scatter', 'label':'LASER original', 's':sz, 'lw':lw, 'color':'r'}
vS2L2 = {'var':dsLRc.S2r*unitscale2, 'r':dsLRc.sep, 'CIs':[dsLRc.CILS2r*unitscale2, dsLRc.CIUS2r*unitscale2], 'method':'scatter', 'label':'LASER chance'  , 's':sz, 'lw':lw, 'color':'forestgreen', 'marker':'x'}
vS2L3 = {'var':dsLRAl.S2*unitscale2/100, 'r':dsLRAl.sep, 'method':'scatter', 'label':'LASER all', 's':sz, 'lw':lw, 'color':'gray', 'marker':'o'}
vS2L4 = {'var':S2L_lunda1[25:50] , 'r':dsLRo.sep[25:50], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid' , 'color':'k'}
vS2L5 = {'var':S2L_Richa1[:36] *3.6, 'r':dsLRo.sep[:36], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vS2L6 = {'var':S2L_Rayla1[35:]    , 'r':dsLRo.sep[35:], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vS2L7 = {'var':S2L_GM1[:36]    *2.6, 'r':dsLRo.sep[:36], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid' , 'color':'azure'}
vS2L55= {'var':S2L_Richa1[:36] *4.0/100, 'r':dsLRo.sep[:36], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vS2L66= {'var':S2L_Rayla1[35:]    /100, 'r':dsLRo.sep[35:], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vS2L77= {'var':S2L_GM1[:36]    *3.4/100, 'r':dsLRo.sep[:36], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid' , 'color':'azure'}

fsleL_lunda = rd.analytic_CIST(dsLRAl.sep, alpha, {'T': 11}, 'Lundgren')
fsleL_Richa = rd.analytic_CIST(dsLRAl.sep, alpha, {'beta': 0.23}, 'Richardson-a')
fsleL_Rayla = rd.analytic_CIST(dsLRAl.sep, alpha, {'k2': 1800}, 'Rayleigh-a')
fsleL_GM    = rd.analytic_CIST(dsLRAl.sep, alpha, {'lambda': 0.5}, '-2-a')
vFL1 = {'var':dsLRo.FSLE, 'r':dsLRo.sep , 'CIs':[dsLRo.CILFSLE, dsLRo.CIUFSLE], 'method':'scatter', 'label':'original pairs', 's':sz, 'lw':lw, 'color':'r'}
vFL2 = {'var':dsLRc.FSLE, 'r':dsLRo.sep , 'CIs':[dsLRc.CILFSLE, dsLRc.CIUFSLE], 'method':'scatter', 'label':'LASER chance', 's':sz, 'lw':lw, 'color':'forestgreen', 'marker':'x'}
vFL3 = {'var':dsLRAl.FSLE_all/100, 'r':dsLRAl.sep, 'method':'scatter', 'label':'all possible pairs', 's':sz, 'lw':lw, 'color':'gray', 'marker':'o'}
vFL4 = {'var':fsleL_lunda[23:37],'r':dsLRAl.sep[23:37], 'method':'plot', 'label':'$E(K)\\sim K^{-3}$', 'lw':1.2, 'linestyle':'solid', 'color':'k'}
vFL5 = {'var':fsleL_Richa[:-16]*1.1, 'r':dsLRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vFL6 = {'var':fsleL_Rayla[35: ]    , 'r':dsLRAl.sep[35: ], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vFL7 = {'var':fsleL_GM[:-16]   *0.84, 'r':dsLRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid', 'color':'azure'}
vFL55= {'var':fsleL_Richa[:-16]*1.1/100, 'r':dsLRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-5/3}$', 'lw':1.2, 'linestyle':'dashed', 'color':'b'}
vFL66= {'var':fsleL_Rayla[35: ]    /100, 'r':dsLRAl.sep[35: ], 'method':'plot', 'label':'diffusive', 'lw':1.2, 'linestyle':'dashdot', 'color':'darkgreen'}
vFL77= {'var':fsleL_GM[:-16]   *0.84/100, 'r':dsLRAl.sep[:-16], 'method':'plot', 'label':'$E(K)\\sim K^{-2}$', 'lw':1.2, 'linestyle':'solid', 'color':'azure'}

fig, axes = pplt.subplots(nrows=2, ncols=2, figsize=(8, 6), facecolor='w', sharex=1, sharey=0, wspace=5.4)

ax = panel(axes[0,0], [vS2G1,vS2G3], [vS2G5,vS2G6,vS2G7,vS2G55,vS2G66,vS2G77], title=f'GLAD $S_2$',
           timebased=False, yscale='log', xscale='log', ylim=[4e-2, 5e3], xlim=[1e-1, 6e2], rebins=None,
           ylabel='$<\\mathbf{v}_i - \\mathbf{v}_j>^2$ ($km^2$ $d^{-2}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [0, 1e4], lw=0.5, linestyle='solid', color='purple')
ax[0].text(0.3, 200, '($r_0=$0.13 km)', fontsize=10)
ax[0].text(50, 4, '(all pairs)', fontsize=10)
ax = panel(axes[0,1], [vFG1,vFG3], [vFG5,vFG6,vFG7,vFG55,vFG66,vFG77], title=f'GLAD FSLE',
           timebased=False, yscale='log', xscale='log', ylim=[7e-4, 2e1], xlim=[1e-1, 6e2], rebins=None,
           ylabel='FSLE ($d^{-1}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [0, 1e4], lw=0.5, linestyle='solid', color='purple')
ax[0].text(3, 7, '($r_0=$0.13 km)', fontsize=10)
ax[0].text(0.2, 0.01, '(all pairs)', fontsize=10)
ax = panel(axes[1,0], [vS2L1,vS2L3], [vS2L5,vS2L6,vS2L7,vS2L55,vS2L66,vS2L77], title=f'LASER $S_2$',
           timebased=False, yscale='log', xscale='log', ylim=[4e-2, 5e3], xlim=[1e-1, 6e2], rebins=None,
           ylabel='$<\\mathbf{v}_i - \\mathbf{v}_j>^2$ ($km^2$ $d^{-2}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [0, 1e4], lw=0.5, linestyle='solid', color='purple')
ax[0].text(0.2, 200, '($r_0=$0.2 km)', fontsize=10)
ax[0].text(70, 4, '(all pairs)', fontsize=10)
ax = panel(axes[1,1], [vFL1,vFL3], [vFL5,vFL6,vFL7,vFL55,vFL66,vFL77], title=f'LASER FSLE',
           timebased=False, yscale='log', xscale='log', ylim=[7e-4, 2e1], xlim=[1e-1, 6e2], rebins=None,
           ylabel='FSLE ($d^{-1}$)', xlabel='$r$ (km)', loc=None, fontsize=10)
ax[0].plot([50, 50], [0, 1e4], lw=0.5, linestyle='solid', color='purple')
ax[0].text(3, 7, '($r_0=$0.2 km)', fontsize=10)
ax[0].text(0.2, 0.01, '(all pairs)', fontsize=10)
lgd = ax[2]
lgd = [lgd[0], lgd[1], lgd[4], lgd[2], lgd[3]]
fig.legend(lgd, loc='b', ncols=5)
axes.format(abc='(a)')
#fig.savefig('fig08.pdf', format='pdf', bbox_inches='tight')
# Out:
# Figure(nrows=2, ncols=2, figwidth=8.0, figheight=6.0)
